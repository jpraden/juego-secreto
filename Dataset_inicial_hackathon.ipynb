# %% [markdown]
# <a href="https://colab.research.google.com/github/jpraden/juego-secreto/blob/main/Dataset_inicial_hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#
import os
import pandas as pd

# %%
# 1. Definición del dataset estructurado según el JSON de entrada requerido
datos_hackathon = [
    # ---- CATEGORÍA: BACKEND ----
    {"titulo": "Introducción a Spring Boot", "texto": "En este contenido se presentan los conceptos básicos para la creación de APIs REST utilizando Java y Spring Boot.", "categoria": "Backend"},
    {"titulo": "Inyección de Dependencias", "texto": "Explicación detallada de cómo gestionar el ciclo de vida de los objetos en Java mediante inversión de control y contenedores de Spring.", "categoria": "Backend"},
    {"titulo": "Optimización de Consultas SQL", "texto": "Aprende a utilizar índices, analizar planes de ejecución y evitar el problema de consultas N+1 en bases de datos relacionales.", "categoria": "Backend"},
    {"titulo": "Manejo de ORM con Hibernate", "texto": "Configuración de entidades, mapeo de relaciones uno a muchos y persistencia de datos eficiente en aplicaciones empresariales.", "categoria": "Backend"},
    {"titulo": "Creación de Middleware en Express", "texto": "Cómo interceptar peticiones HTTP, validar tokens JWT y manejar errores globales en un servidor de Node.js.", "categoria": "Backend"},
    {"titulo": "Arquitectura de Microservicios", "texto": "Diseño de servicios desacoplados utilizando comunicación asíncrona mediante colas de mensajería y event sourcing.", "categoria": "Backend"},

    # ---- CATEGORÍA: FRONTEND ----
    {"titulo": "Gestión de Estado con Redux", "texto": "Uso de actions, reducers y el store global para manejar flujos de datos complejos en aplicaciones SPA con React.", "categoria": "Frontend"},
    {"titulo": "Maquetación Moderna con Tailwind CSS", "texto": "Cómo construir interfaces responsivas utilizando clases utilitarias de CSS y configuraciones de temas personalizados.", "categoria": "Frontend"},
    {"titulo": "Ciclo de Vida de Componentes", "texto": "Uso de los hooks useEffect y useState para controlar el renderizado y los efectos secundarios en componentes funcionales.", "categoria": "Frontend"},
    {"titulo": "Optimización de Bundle Webpack", "texto": "Estrategias de code splitting, lazy loading y tree shaking para reducir el tiempo de carga de aplicaciones web.", "categoria": "Frontend"},
    {"titulo": "Server Side Rendering con Next.js", "texto": "Implementación de renderizado en el servidor y generación de sitios estáticos para mejorar el SEO y rendimiento.", "categoria": "Frontend"},
    {"titulo": "Validación de Formularios con Formik", "texto": "Captura de datos de usuario, esquemas de validación con Yup y manejo de estados de error en componentes de interfaz.", "categoria": "Frontend"},

    # ---- CATEGORÍA: DATA SCIENCE ----
    {"titulo": "Procesamiento de Lenguaje Natural (NLP)", "texto": "Técnicas de limpieza de texto, tokenización, remoción de stopwords y vectorización TF-IDF para modelos de Machine Learning.", "categoria": "Data Science"},
    {"titulo": "Análisis Exploratorio de Datos (EDA)", "texto": "Uso de Pandas, NumPy y Seaborn para identificar valores nulos, distribuciones anomalías y correlaciones estadísticas.", "categoria": "Data Science"},
    {"titulo": "Entrenamiento de Regresión Logística", "texto": "Ajuste de hiperparámetros y evaluación de matrices de confusión para modelos de clasificación binaria y multiclase.", "categoria": "Data Science"},
    {"titulo": "Clustering no Supervisado con K-Means", "texto": "Agrupación de datos clientes basados en similitud geométrica y cálculo del método del codo para hallar el K óptimo.", "categoria": "Data Science"},
    {"titulo": "Redes Neuronales Convolucionales (CNN)", "texto": "Diseño de capas de convolución y pooling en TensorFlow para la clasificación y reconocimiento de imágenes complejas.", "categoria": "Data Science"},
    {"titulo": "Reducción de Dimensionalidad con PCA", "texto": "Aplicación del análisis de componentes principales para simplificar datasets con alta cantidad de variables.", "categoria": "Data Science"},

    # ---- CATEGORÍA: DEVOPS / CLOUD ----
    {"titulo": "Configuración de Buckets en OCI", "texto": "Uso de Oracle Cloud Infrastructure Object Storage para el almacenamiento seguro y persistencia de modelos serializados.", "categoria": "DevOps/Cloud"},
    {"titulo": "Containerización de Aplicaciones con Docker", "texto": "Creación de Dockerfiles optimizados de múltiples etapas para compilar y ejecutar APIs de forma aislada.", "categoria": "DevOps/Cloud"},
    {"titulo": "Pipelines de CI/CD con GitHub Actions", "texto": "Automatización de pruebas unitarias, compilación de imágenes y despliegue continuo en servidores cloud mediante flujos de trabajo.", "categoria": "DevOps/Cloud"},
    {"titulo": "Orquestación de Contenedores con Kubernetes", "texto": "Definición de pods, deployments y services para garantizar la alta disponibilidad y escalado automático de la solución.", "categoria": "DevOps/Cloud"},
    {"titulo": "Infraestructura como Código con Terraform", "texto": "Aprovisionamiento declarativo de recursos de red, instancias compute y bases de datos en la nube de Oracle.", "categoria": "DevOps/Cloud"},
    {"titulo": "Monitoreo y Alertas con Prometheus", "texto": "Configuración de recolección de métricas de servidor y dashboards de Grafana para vigilar la salud de los contenedores.", "categoria": "DevOps/Cloud"},

    # ---- CATEGORÍA: MOBILE ----
    {"titulo": "Gestión de Estado Complejo en Flutter", "texto": "Implementación del patrón BLoC o uso de Provider para separar la lógica de negocio de los widgets de la UI.", "categoria": "Mobile"},
    {"titulo": "Desarrollo Nativo con Kotlin", "texto": "Aprovechamiento de las corrutinas para llamadas asíncronas a APIs y Jetpack Compose para interfaces modernas en Android.", "categoria": "Mobile"},
    {"titulo": "Diseño de Interfaces en iOS con SwiftUI", "texto": "Uso de pilas declarativas, modificadores de vista y animaciones fluidas para el desarrollo en el ecosistema Apple.", "categoria": "Mobile"},
    {"titulo": "Persistencia de Datos Local con Room", "texto": "Implementación de bases de datos SQLite locales para el almacenamiento de caché en aplicaciones móviles sin conexión.", "categoria": "Mobile"},
    {"titulo": "Compilación Multiplataforma con React Native", "texto": "Uso de JavaScript y puentes nativos para desplegar la misma base de código en dispositivos Android e iOS.", "categoria": "Mobile"},
    {"titulo": "Configuración de Notificaciones Push", "texto": "Integración con Firebase Cloud Messaging para el envío de alertas en tiempo real y enganche de usuarios móviles.", "categoria": "Mobile"}
]

# %%
# 2. Creación del DataFrame de Pandas
df = pd.DataFrame(datos_hackathon)

# %%
# #3. Asegurar la creación de la estructura de carpetas local (según nuestro plan)
os.makedirs("data", exist_ok=True)

# %%
# 4. Exportación en los dos formatos clave
# Guardamos en CSV para el entrenamiento de Data Science
df.to_csv("data/dataset_inicial.csv", index=False, encoding="utf-8")

# Guardamos en JSON para simular las peticiones en lote (batch) o pruebas de Back-End
df.to_json("data/dataset_inicial.json", orient="records", force_ascii=False, indent=2)

print("¡Éxito! Dataset base generado en:")
print(" - CSV de entrenamiento: 'data/dataset_inicial.csv'")
print(" - JSON de pruebas: 'data/dataset_inicial.json'")
print(f"Total de registros balanceados: {len(df)} (6 por categoría técnica)")
# Out:
# ¡Éxito! Dataset base generado en:
#  - CSV de entrenamiento: 'data/dataset_inicial.csv'
#  - JSON de pruebas: 'data/dataset_inicial.json'
# Total de registros balanceados: 30 (6 por categoría técnica)
